# %% [markdown]
# # Description of dataset
#
# ## Dataset: World Happiness Report(2016)
#
# * Country
# * Region
# * Happiness Rank
# * Lower Confidence Interval
# * Upper Confidence Interval
# * Economy
# * Family
# * Health
# * Freedom -> Freedom of the individual in the country
# * Trust -> Government Corruption
# * Generosity
# * Dystopia Residual -> Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared. Dystopia Residual is caculated on the six variables(lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support) with all the countries in the dataset.

# %% [markdown]
# # Importing Libraries for Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train=pd.read_csv('happiness dataset.csv')

# %%
train.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
train.tail ()
# Out:
#          Country                           Region  Happiness Rank  \
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 152            3.484                      3.404                      3.564
# 153            3.360                      3.288                      3.432
# 154            3.303                      3.192                      3.414
# 155            3.069                      2.936                      3.202
# 156            2.905                      2.732                      3.078
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
train=train.rename(columns={'Happiness Rank':'Happiness_Rank','Happiness Score':'Happiness_Score'})
train.head()
# Out:
#        Country          Region  Happiness_Rank  Happiness_Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %% [markdown]
# The dataset is already sorted according to the Happiness_Rank and we understand that the top five countries are from Western Europe

# %% [markdown]
# # Missing Data
# We can use seaborn to create a simple heatmap to check for missing data.

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# # We conclude from the heatmap that there are no null values present in the dataset

# %% [markdown]
# # Describing the dataset
#
# * count
# * mean
# * standard deviation
# * Interquartile range
# * maximum value of attributes

# %%
train.describe()
# Out:
#        Happiness_Rank  Happiness_Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %% [markdown]
# # Counting the countries from different regions

# %%
train.Region.value_counts()
# Out:
# Sub-Saharan Africa                 38
# Central and Eastern Europe         29
# Latin America and Caribbean        24
# Western Europe                     21
# Middle East and Northern Africa    19
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
dt = train.Region.value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x = dt.index, y = dt.values)
plt.xlabel('Region')
plt.xticks(rotation = 90)
plt.ylabel('Number of Countries')
plt.title('Number of Countries According to the Region', color = 'blue', fontsize = 20)
plt.show()

# %%
x = sns.stripplot(x = "Region", y = "Happiness_Score", data =train, jitter = True)
plt.xticks(rotation = 90)
plt.title("Countries' Happiness Score According to the Region", color = 'blue', fontsize = 15)
plt.show()

# %% [markdown]
# * Western Europe Countries have the best average happiness score
# * Not enough data to conclude that southern Asia has a poor happiness score
# * Most of the countries in Sub-Saharan Africa have low happiness score

# %% [markdown]
# # Checking Correlation

# %%
f,ax = plt.subplots(figsize = (12, 12))
sns.heatmap(train.corr(), annot = True, linewidths = 0.1, fmt = '.1f', ax = ax, square = True)

# %% [markdown]
# # Hapiness Score correlation with different attributes
# * Strongly correlated with the Economy
# * Strongly correlated with Family
# * Strongly correlated with Health(Life Expectancy)
# * Average correlation with Freedom

# %%
above_mean_HS =['Above World Average' if i >= 5.35 else 'Below World Average' for i in train.Happiness_Score]
df = pd.DataFrame({'Happiness_Score' : above_mean_HS})

sns.countplot(x = df.Happiness_Score)
plt.xlabel('Happiness Score')
plt.ylabel('Number of Countries')
plt.title('Number of Countries based on Happiness Score Average', color = 'blue', fontsize = 15)
plt.show()

# %% [markdown]
# ### No big difference between the number of countries which are above average and the below average

# %%
train.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# # Ingsights from the histogram
#
# * Most of the countries have low corruption level
# * Many countries have life expectancy above 0.5
# * Dystopia Residual is normally distributed
# * Generosity is low among countries

# %%
df=pd.read_csv('happiness dataset.csv',index_col='Region')
df.head()
# Out:
#                     Country  Happiness Rank  Happiness Score  \
# Region
# Western Europe      Denmark               1            7.526
# Western Europe  Switzerland               2            7.509
# Western Europe      Iceland               3            7.501
# Western Europe       Norway               4            7.498
# Western Europe      Finland               5            7.413
#
#                 Lower Confidence Interval  Upper Confidence Interval  \
# Region
# Western Europe                      7.460                      7.592
# Western Europe                      7.428                      7.590
# Western Europe                      7.333                      7.669
# Western Europe                      7.421                      7.575
# Western Europe                      7.351                      7.475
#
#                 Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Region
# Western Europe                   1.44178  1.16374                   0.79504
# ...

# %%
df.loc[['Sub-Saharan Africa'],['Happiness Rank','Country']]
# Out:
#                     Happiness Rank              Country
# Region
# Sub-Saharan Africa              66            Mauritius
# Sub-Saharan Africa              76              Somalia
# Sub-Saharan Africa              97    Somaliland Region
# Sub-Saharan Africa             103              Nigeria
# Sub-Saharan Africa             106               Zambia
# Sub-Saharan Africa             111         Sierra Leone
# Sub-Saharan Africa             113              Namibia
# Sub-Saharan Africa             114             Cameroon
# Sub-Saharan Africa             115             Ethiopia
# Sub-Saharan Africa             116         South Africa
# Sub-Saharan Africa             122                Kenya
# Sub-Saharan Africa             124                Ghana
# Sub-Saharan Africa             125     Congo (Kinshasa)
# Sub-Saharan Africa             127  Congo (Brazzaville)
# Sub-Saharan Africa             128              Senegal
# Sub-Saharan Africa             130           Mauritania
# ...

# %%
df.loc[['Western Europe'],['Happiness Rank','Country']]
# Out:
#                 Happiness Rank         Country
# Region
# Western Europe               1         Denmark
# Western Europe               2     Switzerland
# Western Europe               3         Iceland
# Western Europe               4          Norway
# Western Europe               5         Finland
# Western Europe               7     Netherlands
# Western Europe              10          Sweden
# Western Europe              12         Austria
# Western Europe              16         Germany
# Western Europe              18         Belgium
# Western Europe              19         Ireland
# Western Europe              20      Luxembourg
# Western Europe              23  United Kingdom
# Western Europe              30           Malta
# Western Europe              32          France
# Western Europe              37           Spain
# Western Europe              50           Italy
# Western Europe              62    North Cyprus
# Western Europe              69          Cyprus
# ...

# %% [markdown]
# ## 7 out of the the top 10 countries in the world are from Western Europe

# %%
df.loc[['Southern Asia'],['Happiness Rank','Country']]
# Out:
#                Happiness Rank      Country
# Region
# Southern Asia              84       Bhutan
# Southern Asia              92     Pakistan
# Southern Asia             107        Nepal
# Southern Asia             110   Bangladesh
# Southern Asia             117    Sri Lanka
# Southern Asia             118        India
# Southern Asia             154  Afghanistan

# %% [markdown]
# ## India ranks 118 out of 156 countries

# %%
df.loc[['Eastern Asia'],['Happiness Rank','Country']]
# Out:
#               Happiness Rank      Country
# Region
# Eastern Asia              34       Taiwan
# Eastern Asia              53        Japan
# Eastern Asia              57  South Korea
# Eastern Asia              75    Hong Kong
# Eastern Asia              83        China
# Eastern Asia             101     Mongolia

# %%
df.loc[['North America'],['Happiness Rank','Country']]
# Out:
#                Happiness Rank        Country
# Region
# North America               6         Canada
# North America              13  United States

# %%
df.loc[['Australia and New Zealand'],['Happiness Rank','Country']]
# Out:
#                            Happiness Rank      Country
# Region
# Australia and New Zealand               8  New Zealand
# Australia and New Zealand               9    Australia

# %%
df.loc[['Middle East and Northern Africa'],['Happiness Rank','Country']]
# Out:
#                                  Happiness Rank                  Country
# Region
# Middle East and Northern Africa              11                   Israel
# Middle East and Northern Africa              28     United Arab Emirates
# Middle East and Northern Africa              34             Saudi Arabia
# Middle East and Northern Africa              36                    Qatar
# Middle East and Northern Africa              38                  Algeria
# Middle East and Northern Africa              41                   Kuwait
# Middle East and Northern Africa              42                  Bahrain
# Middle East and Northern Africa              67                    Libya
# Middle East and Northern Africa              78                   Turkey
# Middle East and Northern Africa              80                   Jordan
# Middle East and Northern Africa              90                  Morocco
# Middle East and Northern Africa              93                  Lebanon
# ...

# %%
df.loc[['Latin America and Caribbean'],['Happiness Rank','Country']]
# Out:
#                              Happiness Rank              Country
# Region
# Latin America and Caribbean              14           Costa Rica
# Latin America and Caribbean              15          Puerto Rico
# Latin America and Caribbean              17               Brazil
# Latin America and Caribbean              21               Mexico
# Latin America and Caribbean              24                Chile
# Latin America and Caribbean              25               Panama
# Latin America and Caribbean              26            Argentina
# Latin America and Caribbean              29              Uruguay
# Latin America and Caribbean              31             Colombia
# Latin America and Caribbean              39            Guatemala
# Latin America and Caribbean              40             Suriname
# Latin America and Caribbean              43  Trinidad and Tobago
# Latin America and Caribbean              44            Venezuela
# ...

# %%
df.loc[['Southeastern Asia'],['Happiness Rank','Country']]
# Out:
#                    Happiness Rank      Country
# Region
# Southeastern Asia              22    Singapore
# Southeastern Asia              33     Thailand
# Southeastern Asia              47     Malaysia
# Southeastern Asia              79    Indonesia
# Southeastern Asia              82  Philippines
# Southeastern Asia              96      Vietnam
# Southeastern Asia             102         Laos
# Southeastern Asia             119      Myanmar
# Southeastern Asia             140     Cambodia

# %%
df.loc[['Central and Eastern Europe'],['Happiness Rank','Country']]
# Out:
#                             Happiness Rank                 Country
# Region
# Central and Eastern Europe              27          Czech Republic
# Central and Eastern Europe              45                Slovakia
# Central and Eastern Europe              49              Uzbekistan
# Central and Eastern Europe              54              Kazakhstan
# Central and Eastern Europe              55                 Moldova
# Central and Eastern Europe              56                  Russia
# Central and Eastern Europe              57                  Poland
# Central and Eastern Europe              60               Lithuania
# Central and Eastern Europe              61                 Belarus
# Central and Eastern Europe              63                Slovenia
# Central and Eastern Europe              65            Turkmenistan
# Central and Eastern Europe              68                  Latvia
# Central and Eastern Europe              71                 Romania
# ...

# %% [markdown]
# # My Insights drawn from the Dataset
#
# * Western Europe countries have higher happiness value than other regions.
# * Factors such as GDP, Health, Family and Freedom affect the Happiness Score greatly.
# * Most of the countries are from Africa region.
# * The top five countries are from Western Europe and the bottom five countries are from Africa and Asia region.
# * India Happiness ranks 118 out of 156 countries
#
# ## Top 5 happiest countries from every region
#
# ### Western Europe
#
#  Rank Country
#
# * 1	  Denmark
# * 2	  Switzerland
# * 3	  Iceland
# * 4	  Norway
# * 5	  Finland
#
# ### Sub-Saharan Africa
#
#   Rank  Country
#
# * 66	Mauritius
# * 76	Somalia
# * 97	Somaliland Region
# * 103	Nigeria
# * 106	Zambia
#
# ### Southern Asia
#
#   Rank  Country
#
# * 84	Bhutan
# * 92	Pakistan
# * 107	Nepal
# * 110	Bangladesh
#
# ### Eastern Asia
#
#    Rank  Country
#
# *	34	 Taiwan
# *	53	 Japan
# *	57	 South Korea
# *	75	 Hong Kong
# *	83	 China
#
# ### North America
#
#    Rank   Country
# * 	6	  Canada
# * 	13	 United States
#
# ### Australia and New Zealand
#
#   Rank   Country
#
# *	8	New Zealand
# *	9	Australia
#
# ### Middle East and Northern Africa
#
#    Rank  Country
#
# *	11	 Israel
# *	28	 United Arab Emirates
# *	34	 Saudi Arabia
# *	36	 Qatar
# *	38	 Algeria
#
# ###  Latin America and Caribbean
#
#   Rank  Country
#
# *  14	Costa Rica
# *  15	Puerto Rico
# *  17	Brazil
# *  21	Mexico
# *  24	Chile
#
# ### Southeastern Asia
#
#    Rank          Country
# *	22	      Singapore
# *   33	      Thailand
# *	47	      Malaysia
# *	79	      Indonesia
# *	82	      Philippines
#
# ### Central and Eastern Europe
#
#    Rank   Country
#
# *   27	 Czech Republic
# *	45	 Slovakia
# *	49	 Uzbekistan
# *	54	 Kazakhstan
# *	55	 Moldova
